# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Integracion en hipercubo con centro en c: (1, 0, 0, 0, 6.284, 0) y tamano delta: (0.5, 0.5, 0.5, 1.0547, 1.0547, 1.0547)

# %%
df = pd.read_csv("count_objects.csv")
df['ratio'] = df['numerical_count']/df['theoretical_count']
df
# Out:
#     transformation_type  numerical_count  theoretical_count  \
# 0      uniform_complete                5           4.938991
# 1      uniform_complete                6           4.938991
# 2      uniform_complete                6           4.938991
# 3      uniform_complete                6           4.938991
# 4      uniform_complete                6           4.938991
# ..                  ...              ...                ...
# 155        uniform_aewM           119535      117758.252156
# 156        uniform_aewM           118178      117758.252156
# 157        uniform_aewM           118323      117758.252156
# 158        uniform_aewM           118647      117758.252156
# 159        uniform_aewM           119147      117758.252156
#
#      objects_generated   iteration  Unnamed: 5  Unnamed: 6     ratio
# 0               100000         1.0         NaN         NaN  1.012352
# 1               100000         2.0         NaN         NaN  1.214823
# ...

# %%
df_uniform = df[df['transformation_type'] == 'uniform_aewM']
fig = px.line(df_uniform, x=' iteration', y='ratio', color='objects_generated', markers=True)
fig.update_layout(title=dict(text="Trasformation (a,e,w,M)", font=dict(size=20)))
fig.show()

# %%
df_complete = df[df['transformation_type'] == 'uniform_complete']
fig = px.line(df_complete, x=' iteration', y='ratio', color='objects_generated', markers=True)
fig.update_layout(title=dict(text="Complete Trasformation", font=dict(size=20)))
fig.show()

# %% [markdown]
# ### Integracion en hipercubo con centro en c: (1, 0, 0, 0, 6.284, 0) y tamano delta: (0.2, 0.2, 0.2, 1.0547, 1.0547, 1.0547)

# %%
df2 = pd.read_csv("count_objects2.csv")
df2
# Out:
#        transformation_type  numerical_count  theoretical_count  \
# 0             uniform_aewM              100         117.758252
# 1             uniform_aewM              124         117.758252
# 2             uniform_aewM              125         117.758252
# 3             uniform_aewM              123         117.758252
# 4             uniform_aewM              113         117.758252
# ..                     ...              ...                ...
# 215  uniform_complete_sini             1828        1649.932565
# 216  uniform_complete_sini             1753        1649.932565
# 217  uniform_complete_sini             1738        1649.932565
# 218  uniform_complete_sini             1750        1649.932565
# 219  uniform_complete_sini             1774        1649.932565
#
#      objects_generated   iteration  iteration
# 0               100000         1.0        NaN
# 1               100000         2.0        NaN
# 2               100000         3.0        NaN
# ...

# %%
df_complete2 = df2[df2['transformation_type'] == 'uniform_complete']
df_complete2['ratio'] = df_complete2['numerical_count']/df_complete2['theoretical_count']
df_complete2
# Out:
# C:\Users\INTERPLAY\AppData\Local\Temp\ipykernel_39692\84550993.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     transformation_type  numerical_count  theoretical_count  \
# 80     uniform_complete                3           1.052543
# 81     uniform_complete                0           1.052543
# 82     uniform_complete                1           1.052543
# 83     uniform_complete                2           1.052543
# 84     uniform_complete                3           1.052543
# ..                  ...              ...                ...
# 155    uniform_complete             1054        1052.542834
# 156    uniform_complete             1102        1052.542834
# 157    uniform_complete             1195        1052.542834
# ...

# %%
fig = px.line(df_complete2, x='iteration', y='ratio', color='objects_generated', markers=True)
fig.update_layout(title=dict(text="Complete Trasformation", font=dict(size=20)))
fig.show()

# %%
df_complete3 = df2[df2['transformation_type'] == 'uniform_complete_sini']
df_complete3['ratio'] = df_complete3['numerical_count']/df_complete3['theoretical_count']

fig = px.line(df_complete3, x='iteration', y='ratio', color='objects_generated', markers=True)
fig.update_layout(title=dict(text="Complete Trasformation", font=dict(size=20)))
fig.show()
# Out:
# C:\Users\INTERPLAY\AppData\Local\Temp\ipykernel_39692\2209609495.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_complete3
# Out:
#        transformation_type  numerical_count  theoretical_count  \
# 160  uniform_complete_sini               14          16.499326
# 161  uniform_complete_sini               27          16.499326
# 162  uniform_complete_sini               18          16.499326
# 163  uniform_complete_sini               14          16.499326
# 164  uniform_complete_sini               19          16.499326
# 165  uniform_complete_sini               11          16.499326
# 166  uniform_complete_sini               22          16.499326
# 167  uniform_complete_sini               20          16.499326
# 168  uniform_complete_sini               17          16.499326
# 169  uniform_complete_sini               20          16.499326
# 170  uniform_complete_sini               20          16.499326
# 171  uniform_complete_sini               17          16.499326
# 172  uniform_complete_sini               18          16.499326
# 173  uniform_complete_sini               20          16.499326
# ...
